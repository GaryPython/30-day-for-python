# %%
import matplotlib.pyplot as plt

# %%
years = [1000,1500,1600,1700,1750,1800,1850,
        1900,1950,1960,1965,1970,1975,1980,
        1985,1990,1995,2000,2005,
        2010,2015]

pops = [200,400,458,580,662,791,1000,
        1262,1650,2525,2758,3018,3322,3682,
        4061,4440,4853,5310,6520,
        6930,7349]
plt.plot(years,pops)
plt.show()

# %%
years = [1950,1960,1965,1970,1975,1980,
        1985,1990,1995,2000,2005,
        2010,2015]
pops = [2.5,2.7,3,3.3,3.6,4.0,
        4.4,4.8,5.3,6.1,6.5,6.9,7.3]
plt.plot(years,pops,color=(255/255,100/255,100/255))#改變線條的顏色
plt.title("Population Growth") # title
plt.ylabel("Population in billions") # y y座標
plt.xlabel("Population growth by year") # x label x座標
plt.show()

# %%
deaths = [1.2,1.7,1.8,2.2,2.5,2.7,2.9,3,3.1,3.2,3.5,3.6,4]
plt.plot(years,pops, color='Blue')
plt.plot(years,deaths, '--', color='Black')
plt.title("Population Growth") # title
plt.ylabel("Population in billions",color ='R') # y label
plt.xlabel("Population growth by year") # x label
plt.show()

# %%
#兩條線法一
deaths = [1.2,1.7,1.8,2.2,2.5,2.7,2.9,3,3.1,3.2,3.5,3.6,4]
plt.plot(years,pops, color='Blue')
plt.plot(years,deaths, '--', color='Black')#'--'線
plt.title("Population Growth") # title
plt.ylabel("Population in billions",color ='R') # y label
plt.xlabel("Population growth by year") # x label
plt.show()

# %%
#兩條線法二
deaths = [1.2,1.7,1.8,2.2,2.5,2.7,2.9,3,3.1,3.2,3.5,3.6,4]
lines = plt.plot(years,pops,years,deaths)
plt.title("Population Growth") # title
plt.ylabel("Population in billions",color ='R') # y label
plt.xlabel("Population growth by year") # x 
plt.grid(True)#網格
plt.show()

# %%
deaths = [1.2,1.7,1.8,2.2,2.5,2.7,2.9,3,3.1,3.2,3.5,3.6,4]
lines = plt.plot(years,pops,years,deaths)
plt.setp(lines,marker='o',linewidth = 3 ,color ='R')#設定'o'點點樣式 linewidth線寬 
plt.title("Population Growth") # title
plt.ylabel("Population in billions",color ='R') # y label
plt.xlabel("Population growth by year") # x 
plt.grid(True)#網格
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0, 1.0, 0.01)
y1 = np.sin(4*np.pi*x)
y2 = np.sin(2*np.pi*x)
lines = plt.plot(x, y1, x, y2)
plt.setp(lines, linestyle='--')      
plt.show()

# %%
#統整
#圓餅圖
import matplotlib.pyplot as plt
labels = ['A','B','C','D','E','F'] #加入label
size = [33,52,12,17,62,48]#設定每塊的大小
plt.pie(size , labels = labels,autopct='%1.1f%%')#pie 圓餅圖autopct='%1.1f%%'是用來顯示百分比
plt.axis('equal')#圓餅圖比例相等加上
plt.show()

# %%
#統整
#圓餅圖
import matplotlib.pyplot as plt
labels = ['A','B','C','D','E','F'] #加入label
size = [33,52,12,17,62,48]#設定每塊的大小
separated = (0,.1,0,0,0,0)#[ABCDEF]分離
plt.pie(size , labels = labels,autopct='%1.1f%%',explode=separated)#pie 圓餅圖autopct='%1.1f%%'是用來顯示百分比
plt.axis('equal')#圓餅圖比例相等加上
plt.show()

# %%
#圓餅圖
import matplotlib.pyplot as plt
import pandas as pd
#先定義資料
data = {'names':['a','b','c','d','e'],
        'jan':[133,122,101,104,320],
        'feb':[122,132,144,98,62],
        'march':[64,99,32,12,65] }
#接著將資料設定為DataFrame資料格式，放到變數df
df = pd.DataFrame(data,columns=['names','jan','feb','march'])
#定義（總）大小
df['total'] = df['jan']+ df['feb']+df['march']
#a (133+122+64)/(133+122+101+104+320+122+132+144+98+62+64+99+32+12+65) =0.19813665
#定義顏色
colors = [(1,.4,.4),(1,.6,1),(.5,.3,1),(.7,.7,.2),(.6,.2,.6)]
plt.pie( df['total'] ,
    labels = df['names'],
    colors = colors,
    autopct='%1.1f%%',
    ) 
plt.axis('equal')
plt.show()

# %%
#長條圖
import matplotlib.pyplot as plt
import numpy as np
col_count = 3
A_scores = (553,536,548)
B_scores = (518,523,523)
C_scores = (613,570,588)
D_scores = (475,505,499)
index = np.arange(col_count)
k = plt.bar(index,A_scores, .5)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
col_count = 3
bar_width = 0.2#線寬
index = np.arange(col_count)
A_scores = (557,536,548)
B_scores = (518,523,523)
C_scores = (613,570,588)
D_scores = (475,505,499)
#定義bar的圖型
A = plt.bar(index,
           A_scores, 
           bar_width,
           alpha=.4,
           label="K") 
B = plt.bar(index+0.2,
            B_scores,
            bar_width,
            alpha=.4,
            label="C") 
C = plt.bar(index+0.4,
            C_scores,
            bar_width,
            alpha=.4,
            label="N") # x,y ,width
D = plt.bar(index+0.6,
            D_scores,
            bar_width,
            alpha=.4,
            label="F")
#每個長條圖上面都有顯示文字：
def createLabels(data):
    for item in data:
        height = item.get_height()
        plt.text(
            item.get_x()+item.get_width()/2., 
            height*1.05, 
            int(height),
            ha = "center",
            va = "bottom",
        )
createLabels(A)
createLabels(B)
createLabels(C)
createLabels(D)
plt.ylabel("Mean score")
plt.xlabel("Subject")
plt.title("Test Scores by Contry")
plt.xticks(index+.3/2  ,("Math","Reading","Science"))
plt.legend() 
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
col_count = 3
bar_width = 0.2#線寬
index = np.arange(col_count)
A_scores = (553,536,548)
B_scores = (518,523,523)
C_scores = (613,570,588)
D_scores = (475,505,499)
#定義bar的圖型
A = plt.bar(index,
           A_scores, 
           bar_width,
           alpha=.4,
           label="K") 
B = plt.bar(index+0.2,
            B_scores,
            bar_width,
            alpha=.4,
            label="C") 
C = plt.bar(index+0.4,
           C_scores,
           bar_width,
           alpha=.4,
           label="N") # x,y ,width
D = plt.bar(index+0.6,
            D_scores,
            bar_width,
            alpha=.4,
            label="F")
#每個長條圖上面都有顯示文字：
def createLabels(data):
    for item in data:
        height = item.get_height()
        plt.text(
            item.get_x()+item.get_width()/2., 
            height*1.05, 
            '%d' % int(height),
            ha = "center",
            va = "bottom",
        )
#每個長條圖上面都有顯示文字：(改編)
# def createLabels(data):
#     for item in data:
#         y = item.get_height()
#         x = item.get_x()+item.get_width()/2.
#         plt.text(
#             x, 
#             y*1.05, 
#             '%d' % int(y),
#             ha = "center",
#             va = "bottom",
#         )
createLabels(A)
createLabels(B)
createLabels(C)
createLabels(D)
plt.ylabel("Mean score")
plt.xlabel("Subject")
plt.title("Test Scores by Contry")
plt.xticks(index+.3 / 2 ,("Math","Reading","Science"))
plt.legend() 
plt.grid(True)
plt.show()

# %%
#練習
import matplotlib.pyplot as plt
import numpy as np
col_count = 3
bar_width = 0.2#線寬
index = np.arange(col_count)
A_scores = (553,536,548)
B_scores = (518,523,523)
C_scores = (613,570,588)
D_scores = (475,505,499)
A = plt.bar(index,
           A_scores, 
           bar_width,
           alpha=.4,
           label="K") 
def createLabels(data):
    for item in data:
        height = item.get_height()
        plt.text(
            item.get_x()+item.get_width()/2, 
            height*1.05, 
            '%d' % int(height),
            ha = "center",
            va = "bottom",
        )
createLabels(A)
plt.ylabel("Mean score")
plt.xlabel("Subject")
plt.title("Test Scores by Contry")
plt.xticks(index+.3 / 2 ,("Math","Reading","Science"))
plt.legend() 
plt.grid(True)
plt.show()

# %%
#pandas 繪圖
import pandas as pd
#使用yahoo資料
pd.core.common.is_list_like = pd.api.types.is_list_like
#pandas-datareader抓股票
import pandas_datareader.data as web
import datetime
#定義資料
#上面這邊引入了yahoo上"F"也就是Finance的資料，並給予要抓取的開始時間start與結束時間end
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2020, 8, 1)
data = web.DataReader("F", 'yahoo', start, end)
data.plot()
data.plot(y="Close")
data
# Out:
#              High    Low   Open  Close       Volume  Adj Close
# Date
# 2016-01-04  14.00  13.75  13.87  13.97   38618500.0  11.050024
# 2016-01-05  14.00  13.51  13.97  13.72   50267500.0  10.852281
# 2016-01-06  13.56  13.05  13.56  13.11   61285500.0  10.369781
# 2016-01-07  13.04  12.60  12.90  12.70   57846700.0  10.045479
# 2016-01-08  13.10  12.50  13.05  12.54   46199400.0   9.918921
# ...           ...    ...    ...    ...          ...        ...
# 2020-07-27   6.94   6.77   6.92   6.93   60370200.0   6.930000
# 2020-07-28   7.05   6.90   6.90   7.01   56312500.0   7.010000
# 2020-07-29   7.06   6.83   7.05   6.92   59437200.0   6.920000
# 2020-07-30   6.83   6.67   6.74   6.74   58991000.0   6.740000
# 2020-07-31   6.90   6.52   6.89   6.61  115394100.0   6.610000
#
# [1153 rows x 6 columns]

# %%
data["Close"].plot()
#取兩個用list格式就可以
data[["High","Low"]].plot()

# %%
#用numpy作圖
import numpy as np
df = pd.DataFrame(np.random.randn(100, 4), index=pd.date_range('12/31/2017', periods=100), columns=list('ABCD'))
df = df.cumsum()#累加
df.plot()

df_1 = pd.DataFrame(np.random.randn(100, 4), index=pd.date_range('12/31/2017', periods=100), columns=list('ABCD'))
df_1.plot()
