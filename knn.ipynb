# %%
from sklearn import datasets#用鳶尾花的資料集做測試
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

iris = datasets.load_iris()
iris_data = iris.data
iris_label = iris.target
iris_data[0:3]

# %%
train_data , test_data , train_label , test_label = train_test_split(iris_data,iris_label,test_size=0.2)
knn = KNeighborsClassifier()
knn.fit(train_data,train_label)

# %%
print(knn.predict(test_data))
print(test_label)

# %%
# train_test_split練習一
# data = [n for n in range(1, 11)]
# print(data)
# from sklearn.model_selection import train_test_split
# train_data, test_data = train_test_split(data, random_state=6, test_size=0.8)
# print(train_data)
# print(test_data)

# %%
# train_test_split練習二
# import numpy as np
# from sklearn.model_selection import train_test_split
# X, y = np.arange(30).reshape((10, 3)), np.arange(10)
# X_train, X_test ,y_train, y_test= train_test_split(X, y,test_size=0.3, random_state = 2, shuffle=True)
# print(X_test)
# print(X_train)
# print(y_test)
# print(y_train)

# %%
from sklearn import datasets#用鳶尾花的資料集做測試
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

iris = datasets.load_iris()
iris_data = iris.data
iris_label = iris.target
iris_data[0:3]
train_data , test_data , train_label , test_label = train_test_split(iris_data,iris_label,test_size=0.8)
print(test_label)
print(train_label)
print(test_data)
print(train_data)
