# %%
import pandas as pd
pd.__version__
# Out:
# '1.0.5'

# %%
my_obj = pd.Series([4, 7, -5, 3])#index 沒有設定過

# %%
my_obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
my_obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
my_obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
my_obj[0]
# Out:
# 4

# %%
my_obj2 = pd.Series([8,9,10,11], index=['a','b','c','d'])
# index 有設定過

# %%
my_obj2
# Out:
# a     8
# b     9
# c    10
# d    11
# dtype: int64

# %%
my_obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
my_obj2['a']
# Out:
# 8

# %%
'a' in my_obj2
# Out:
# True

# %%
#這裡我們先宣告一個dictinary，接著轉成Series：
dic_data = {'name':'apple','birthday':'1996-1-1','luckynumber':7 }
my_obj3 = pd.Series(dic_data)
my_obj3
# Out:
# name              apple
# birthday       1996-1-1
# luckynumber           7
# dtype: object

# %%
my_obj3.values
# Out:
# array(['apple', '1996-1-1', 7], dtype=object)

# %%
my_obj3.index
# Out:
# Index(['name', 'birthday', 'luckynumber'], dtype='object')

# %%
registration = [True,False,True,True]
registration = pd.Series(registration)
registration
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
dictionary = {'A':'an animal',
              'B':'a color',
              'C':'a fruit'}
dictionary = pd.Series(dictionary)
dictionary
# Out:
# A    an animal
# B      a color
# C      a fruit
# dtype: object
