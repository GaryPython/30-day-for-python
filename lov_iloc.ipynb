# %%
import pandas as pd

# %%
#Series
seriesObj = pd.Series(range(10),index=['a', 'a', 'b', 'b', 'b','c','c','c','c','c'])
seriesObj['c']
# Out:
# c    5
# c    6
# c    7
# c    8
# c    9
# dtype: int64

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(4,4),index=list('abcd'), columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# a  0.211529 -0.269732 -1.477645  0.135546
# b -0.275541  1.187943  1.610890  1.716708
# c  0.339758  0.025001  1.019599  1.276729
# d  0.870032 -1.544919 -1.355076  0.021007

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(4,4),index=['a','b', 'c', 'd'], columns=['A','B', 'C', 'd'])
df
# Out:
#           A         B         C         d
# a -0.575225 -0.877260 -0.624921  0.049475
# b  1.226094  0.057661  0.417767  0.881706
# c  1.642109  1.078000 -0.409145  0.667482
# d  0.315254  0.477584 -0.844166  1.403430

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(4,2),index=['a', 'a', 'b', 'b'])
df
# Out:
#           0         1
# a  1.491965  0.183421
# a -1.356976 -1.306488
# b -1.513126  0.978533
# b  1.818500  0.314644

# %%
df.loc['b', :]
# Out:
#           0         1
# b -1.513126  0.978533
# b  1.818500  0.314644

# %%
"Hello my name is jiayi".split(" ")
# Out:
# ['Hello', 'my', 'name', 'is', 'jiayi']
